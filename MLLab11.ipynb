# %% [markdown]
# Ali Hisham AlJamed 2240005868 6MA1 / MA01

# %% [markdown]
# ARTI308 - Machine Learning
#
# # Credit Card Customer Segmentation Project
#
# In this project, you will use K-Means clustering to segment [credit card customers](https://www.kaggle.com/datasets/arjunbhasin2013/ccdata/data) based on their usage behavior. This is an unsupervised learning problem because the dataset does not contain a target label for customer groups.
#
# You will use the `CC_GENERAL.csv` dataset.

# %% [markdown]
# ## About the Dataset
#
# The dataset contains customer-level credit card usage behavior. Each row represents one credit card holder, and the columns describe different behavioral variables such as balance, purchases, cash advance, payments, and tenure. The goal is to group similar customers together so that the company can understand different customer segments and design better marketing strategies.

# %% [markdown]
# ## Import Libraries
#
# **Import the libraries you need for data analysis, visualization, preprocessing, clustering, and evaluation.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Get the Data
#
# **Read the `CC_GENERAL.csv` file and save it in a dataframe called `df`.**

# %%
 df = pd.read_csv('CC_GENERAL.csv')

# %% [markdown]
# **Check the first five rows of the dataset.**

# %%
 df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# **Check the shape of the dataset.**

# %%
 print(df.shape)
# Out:
# (8950, 18)

# %% [markdown]
# **Check basic information about the dataset using `info()`.**

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# **Check summary statistics using `describe()`.**

# %%
 df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# ## Data Cleaning
#
# The column `CUST_ID` is an identification column. It is not useful for clustering because it does not describe customer behavior.
#
# **Drop the `CUST_ID` column from the dataframe.**

# %%
df = df.drop('CUST_ID', axis = 1)
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# **Check the missing values in each column.**

# %%
 df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# Some columns may contain missing values.
#
# Hint: You can handle missing values by either:
# - filling them with the mean value
# - or dropping the rows that contain missing values
#
# For this project, use mean imputation.
#
# **Fill the missing values with the mean of each column.**

# %%
 df = df.fillna(df.mean(numeric_only = True))

# %% [markdown]
# **Check the missing values again to make sure they were handled.**

# %%
 df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis
#
# Before applying clustering, it is important to understand the data.
#
# **Create histograms for the numerical columns.**

# %%
df.hist(figsize=(15,12), bins=20)
plt.show()

# %% [markdown]
# **Create a correlation heatmap to understand relationships between the features.**

# %%
plt.figure(figsize = (12,10))
sns.heatmap(df.corr(),cmap = 'coolwarm')
plt.show()

# %% [markdown]
# **Create a scatter plot between `BALANCE` and `PURCHASES`.**

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['BALANCE'],df['PURCHASES'])
plt.xlabel('Balance')
plt.ylabel('Purchases')
plt.show()

# %% [markdown]
# **Create a scatter plot between `BALANCE` and `CASH_ADVANCE`.**

# %%
 plt.figure(figsize=(8,6))
plt.scatter(df['BALANCE'],df['CASH_ADVANCE'])
plt.xlabel('Balance')
plt.ylabel('Cash_Advance')
plt.show()

# %% [markdown]
# ## Feature Scaling
#
# K-Means is a distance-based algorithm. Therefore, feature scaling is very important.
#
# The features in this dataset have very different ranges. For example, `BALANCE`, `PURCHASES`, and `CREDIT_LIMIT` may have large values, while frequency columns are between 0 and 1.
#
# **Use StandardScaler to scale the data. Save the scaled data in a variable called `X_scaled`.**

# %%
 from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(df)

# %% [markdown]
# ## Choosing K Intuitively
#
# Choosing K is one of the most difficult parts of K-Means.
#
# Since this dataset has many features, it is not easy to visually see the clusters directly.
#
# However, we can still compare different K values using the elbow method and silhouette score.

# %% [markdown]
# ## Elbow Method
#
# **Create a loop that fits K-Means models for K values from 1 to 10. Save the inertia values in a list called `inertia_values`.**

# %%
 from sklearn.cluster import KMeans

inertia_values = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia_values.append(kmeans.inertia_)
    print(inertia_values)
# Out:
# [152149.99999999994]
# [152149.99999999994, 128957.909553381]
# [152149.99999999994, 128957.909553381, 112609.01071221907]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852, 92157.23090613533]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852, 92157.23090613533, 84852.5940022628]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852, 92157.23090613533, 84852.5940022628, 80786.09414150049]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852, 92157.23090613533, 84852.5940022628, 80786.09414150049, 76542.39710611732]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852, 92157.23090613533, 84852.5940022628, 80786.09414150049, 76542.39710611732, 71729.80111888572]
# [152149.99999999994, 128957.909553381, 112609.01071221907, 105366.56908176852, 92157.23090613533, 84852.5940022628, 80786.09414150049, 76542.39710611732, 71729.80111888572, 66612.69244066975]
# C:\Users\Ali_PC\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Ali_PC\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\Ali_PC\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ali_PC\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ali_PC\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^

# %% [markdown]
# **Plot the elbow curve.**

# %%
plt.figure(figsize=(8,6))
plt.plot(range(1,11), inertia_values, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# **Output Interpretation**
#
# Look at the elbow curve and try to identify where the decrease in inertia starts to slow down.
#
# That point can suggest a reasonable value for K.

# %% [markdown]
# ## Silhouette Score
#
# The silhouette score helps evaluate how well-separated the clusters are.
#
# **Create a loop that calculates the silhouette score for K values from 2 to 10. Save the scores in a list called `silhouette_scores`.**

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    score = silhouette_score(X_scaled, labels)
    silhouette_scores.append(score)

# %% [markdown]
# **Plot the silhouette scores.**

# %%
 import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.plot(range(2,11), silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Analysis')
plt.grid(True)
plt.show()

# %% [markdown]
# **Create a table showing each K value and its silhouette score.**

# %%
 import pandas as pd

silhouette_table = pd.DataFrame({
    'K': range(2,11),
    'Silhouette Score': silhouette_scores
})

silhouette_table
# Out:
#     K  Silhouette Score
# 0   2          0.279913
# 1   3          0.206761
# 2   4          0.166392
# 3   5          0.192346
# 4   6          0.202755
# 5   7          0.194870
# 6   8          0.189973
# 7   9          0.201655
# 8  10          0.220518

# %% [markdown]
# **Output Interpretation**
#
# A higher silhouette score usually means better clustering.
#
# However, do not rely only on the highest value. Also consider whether the chosen K makes sense for customer segmentation.

# %% [markdown]
# ## Create the Final K-Means Model
#
# **Based on the elbow curve and silhouette scores, choose a final K value. Then train a final K-Means model.**
#
# Use `random_state=42` and `n_init=10`.

# %%
 from sklearn.cluster import KMeans

final_k = 2   # Replace with your chosen K

kmeans = KMeans(
    n_clusters=final_k,
    random_state=42,
    n_init=10
)

clusters = kmeans.fit_predict(X_scaled)

# %% [markdown]
# **Add the final cluster labels to the original dataframe in a new column called `Cluster`.**

# %%
 df['Cluster'] = clusters

# %% [markdown]
# **Check the first five rows after adding the cluster labels.**

# %%
 df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  Cluster
# 0   201.802084        139.509787          0.000000      12        1
# 1  4103.032597       1072.340217          0.222222      12        1
# 2   622.066742        627.284787          0.000000      12        0
# 3     0.000000        864.206542          0.000000      12        1
# 4   678.334763        244.791237          0.000000      12        1

# %% [markdown]
# ## Cluster Analysis
#
# Now we need to understand what each cluster means.
#
# **Create a summary table using `groupby()` to show the mean values of each feature for each cluster.**

# %%
cluster_summary = df.groupby('Cluster').mean()

cluster_summary
# Out:
#             BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        1380.53426           0.945613  2029.278249       1143.949404
# 1        1694.52779           0.828950   277.731984        202.497431
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                    885.659164    442.612314             0.906030
# 1                     75.513427   1358.026437             0.196449
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                          0.362236                          0.731993
# 1                          0.089488                          0.104561
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# Cluster
# 0                      0.058736          1.420556      30.738063
# 1                      0.189168          4.541484       3.377265
#
#          CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  \
# Cluster
# 0         5107.558741  2192.796616        874.605367          0.271074
# 1         4060.957911  1408.151902        856.854179          0.070737
#
#             TENURE
# Cluster
# 0        11.678716
# 1        11.403204

# %% [markdown]
# **Check how many customers are in each cluster.**

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 1    5243
# 0    3707
# Name: count, dtype: int64

# %% [markdown]
# ## Visualizing the Final Clusters
#
# Since the dataset has many features, we will use PCA to reduce the data into two components only for visualization.
#
# This visualization does not replace the original clustering. It only helps us see the clusters in a 2D plot.
#
# **Use PCA with 2 components and plot the clusters.**

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
pca_components = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(
    data=pca_components,
    columns=['PC1', 'PC2']
)

pca_df['Cluster'] = clusters

plt.figure(figsize=(10, 7))

for cluster in sorted(pca_df['Cluster'].unique()):
    subset = pca_df[pca_df['Cluster'] == cluster]

    plt.scatter(
        subset['PC1'],
        subset['PC2'],
        label=f'Cluster {cluster}'
    )

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Customer Segments (PCA Visualization)')
plt.legend()
plt.show()

# %% [markdown]
# **Output Interpretation**
#
# The PCA plot gives a simplified 2D view of the clusters.
#
# If the clusters are not perfectly separated, that is normal because the original dataset has many features and the plot only shows two compressed dimensions.

# %%
df.groupby('Cluster')[[
    'BALANCE',
    'BALANCE_FREQUENCY',
    'PURCHASES',
    'ONEOFF_PURCHASES',
    'INSTALLMENTS_PURCHASES',
    'CASH_ADVANCE',
    'PURCHASES_FREQUENCY',
    'ONEOFF_PURCHASES_FREQUENCY',
    'PURCHASES_INSTALLMENTS_FREQUENCY',
    'CASH_ADVANCE_FREQUENCY',
    'CASH_ADVANCE_TRX',	
    'PURCHASES_TRX',
    'CREDIT_LIMIT',
    'PAYMENTS',
    'MINIMUM_PAYMENTS',
    'PRC_FULL_PAYMENT',
    'TENURE'	
]].mean()
# Out:
#             BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        1380.53426           0.945613  2029.278249       1143.949404
# 1        1694.52779           0.828950   277.731984        202.497431
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                    885.659164    442.612314             0.906030
# 1                     75.513427   1358.026437             0.196449
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                          0.362236                          0.731993
# 1                          0.089488                          0.104561
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# Cluster
# 0                      0.058736          1.420556      30.738063
# 1                      0.189168          4.541484       3.377265
#
#          CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  \
# Cluster
# 0         5107.558741  2192.796616        874.605367          0.271074
# 1         4060.957911  1408.151902        856.854179          0.070737
#
#             TENURE
# Cluster
# 0        11.678716
# 1        11.403204

# %% [markdown]
# ## Final Questions
#
# Answer the following questions:
#
# 1. Why is this an unsupervised learning problem?
#
# 2. Why did we remove the `CUST_ID` column?
#
# 3. Which columns had missing values?
#
# 4. How did you handle the missing values?
#
# 5. Why is scaling important before applying K-Means?
#
# 6. Which K value did you choose? Explain your answer using the elbow method and silhouette score.
#
# 7. Based on the cluster summary table, describe each customer segment in your own words.
#
# 8. Which cluster may represent high-value customers?
#
# 9. Which cluster may represent customers who rely more on cash advance?
#
# 10. How can a company use these clusters for marketing strategy?

# %% [markdown]
# 1- Why is this an unsupervised learning problem?
#
# This is an unsupervised learning problem because there is no target variable or known label indicating which customer belongs to which group. The goal is to discover natural patterns and customer segments from the data using clustering.
#
# 2- Why did we remove the CUST_ID column?
#
# The CUST_ID column is simply a unique identifier for each customer and does not contain meaningful behavioral information. Including it could distort the clustering process because K-Means would treat it as a numerical feature even though it has no relationship to customer behavior.
#
# 3- Which columns had missing values?
#
# Credit Limit and Minimum Payment.
#
# 4- How did you handle the missing values?
#
# The missing values were replaced using the mean value of their respective columns. df = df.fillna(df.mean(numeric_only=True)).
#
# 5- Why is scaling important before applying K-Means?
#
# K-Means uses distance calculations to form clusters. Features with larger numerical ranges can dominate the distance calculations and have a disproportionate influence on the clustering results. Scaling ensures that all features contribute equally to the clustering process.
#
# 6- Which K value did you choose? Explain your answer using the elbow method and silhouette score.
#
# The silhouette analysis showed that K = 2 produced the highest silhouette score (0.28), indicating the best cluster separation among the tested values. The elbow curve also suggested that increasing the number of clusters beyond this point provided diminishing improvements in inertia. Therefore, K = 2 was chosen as the optimal number of clusters.
#
# 7- Based on the cluster summary table, describe each customer segment in your own words.
#
# Cluster 0: Purchase-Oriented Customers
#
# Higher purchase amounts.
# Higher one-off purchases.
# Higher installment purchases.
# More frequent card usage.
# Lower cash advance usage.
#
# These customers actively use their credit cards for spending and purchases.
#
# Cluster 1: Cash-Advance-Oriented Customers
#
# Lower purchasing activity.
# Higher reliance on cash advances.
# Less frequent purchasing behavior.
#
# These customers appear to use their credit cards more as a source of cash rather than for regular purchases.
#
# 8- Which cluster may represent high-value customers?
#
# Cluster 0 likely represents high-value customers because they generate more purchase activity, make larger transactions, and use their credit cards more frequently for spending.
#
# 9- Which cluster may represent customers who rely more on cash advance?
#
# Cluster 1.
#
# 10- How can a company use these clusters for marketing strategy?
#
# The company can tailor its marketing efforts to each customer segment:
#
# Cluster 0 (Purchase-Oriented Customers):
# Offer premium rewards programs.
# Provide cashback promotions.
# Promote loyalty and travel benefits.
# Encourage higher spending through targeted offers.
# Cluster 1 (Cash-Advance-Oriented Customers):
# Offer financial planning tools.
# Promote lower-interest repayment options.
# Encourage greater use of purchase-based rewards.
# Provide educational content about responsible credit usage.
#
# By targeting each segment differently, the company can improve customer satisfaction, increase revenue, and design more effective marketing campaigns.
